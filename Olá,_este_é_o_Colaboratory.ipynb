# %% [markdown]
# <a href="https://colab.research.google.com/github/Francelinojr/TRABALHO-ICD/blob/main/Ol%C3%A1%2C_este_%C3%A9_o_Colaboratory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np 
import os 
import pandas as pd
from scipy import stats
import warnings
sns.set_theme(style="darkgrid")
warnings.simplefilter(action="ignore", category=FutureWarning)
# %matplotlib inline

master = pd.read_csv("master.csv")
master
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
ax = sns.countplot(x="type", data=master, palette="Set1")

# %%
master.rename(columns={"show_id":"type","title":"director	",
                  "cast":"country","date_added":"release_year",
                    "rating	":"duration","listed_in":"description"}, inplace=True)
print(master.columns)
# Out:
# Index(['type', 'type', 'director\t', 'director', 'country', 'country',
#        'release_year', 'release_year', 'rating', 'duration', 'description',
#        'description'],
#       dtype='object')

# %%
master=pd.read_csv("master.csv")
master.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
ax = sns.countplot(x="type", data=master, palette="Set1")

# %%
ax = sns.lineplot(data=master, x="type", y="release_year", hue="release_year")

# %%
plt.figure(figsize=(12,10))
sns.set(style="darkgrid")
ax = sns.countplot(y="release_year", data=master , palette="Set1", order=master['release_year'].value_counts().index[0:15])

# %%
ax = sns.scatterplot(data=master, x="release_year", y="release_year")
